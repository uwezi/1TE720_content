# %% [markdown]
# # Kurvanpassning av en dämpad oscillation
# Experimentet utfördes med ett accelerometer som var fäst på en gunga. Gungans (pendelns) amplitud och dess maximala vinkelhastighet avtar exponentiellt med tiden medan pendeln själv följer en nästan perfekt harmonisk oscillation. Vi ska betrakta här vinkelhastigheten av pendeln.

# %% [markdown]
# Först som vanligt - några externa bibliotek:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 9]
import scipy.optimize as opt
import numpy as np
from IPython.display import display, Math, Markdown

# %% [markdown]
# Vi ska analysera data som befinner sig i filen "20150224_accgyro_cal.txt" i samma katalog som vår skript.<br/>
# Filen innehåller 5942 rader med mätdata i tre kolumner:
#
# 1. en tid (i sekunder) för mätningen
# 1. den uppmätta accelerationen (i $m/s^2$) vid tidpunkten
# 1. den uppmätta vinkelhastigheten (i $^o/s$)
#
# som vi läser in i tre python-listor `tid`, `acc` och `vel`.<br/>
# Sedan rättar vi till tidsaxeln genom att sätta första tidpunkten till `tid=0`

# %%
tid, acc, vel = np.loadtxt("20150224_accgyro_cal.txt", unpack=True)
tid = tid - min(tid)  # subtraherar min(tid) från alla tidpunkter

# %% [markdown]
# Hur ser datan ut då?<br/>
# Vi gör en snabb plot:

# %%
fig, ax = plt.subplots()
ax.plot(tid, acc, label="acceleration", color="red", linestyle="", marker="+", markersize=5)
ax.plot(tid, vel, label="vinkelhastighet", color="blue", linestyle="", marker="+", markersize=5)
ax.legend()

# %% [markdown]
# Vinkelhastighetens amplitud avtar med tiden. Kan vi göra en kurvanpassning?
#
# Vi kan utgå från följande modellfunktion:<br/>
# $f(t) = A\sin\left(2\pi B t + C\right)\cdot e^{-D t}$<br/>
# där $A$ är den ursprungliga amplituden vid $t=0$, $B$ är frekvensen, $C$ är en fasförskjutning och $D$ står för den expontiella dämpningen.

# %%
def f(t, A, B, C, D):
    return A*np.sin(2*np.pi*B*t + C)*np.exp(-D*t)

# %% [markdown]
# Hur ser denna funktion ut allmänt?
#
# Vi gör en graf för
# $f(t) = 100\sin\left(2\pi t + 0\right)\cdot e^{-0.1 t}$

# %%
guessParams = [10, 1, 0, 0.1]


fig, ax = plt.subplots()
ax.plot(tid, f(tid, *guessParams), label="exponentiell dämpad oscillation",
        color="red", linestyle="-", marker="", linewidth=2)
ax.plot(tid, vel, label="vinkelhastighet", color="blue", linestyle="", marker="+", markersize=5, alpha=0.1)
ax.legend()

# %% [markdown]
# Och nu låter vi Python hitta en kurvanpassning med `opt.curve_fit()`<br/>
# Kommer Python att lyckas?

# %%
optimParams, pcov = opt.curve_fit(f=f, xdata=tid, ydata=vel, p0=guessParams, method="trf", verbose=2)
# Out:
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.8106e+06                                    1.23e+06
#        1              2         2.7068e+06      1.04e+05       1.00e+01       2.06e+06
#        2              8         2.6855e+06      2.13e+04       1.95e-02       6.84e+05
#        3              9         2.6812e+06      4.30e+03       1.95e-02       1.69e+06
#        4             10         2.6781e+06      3.11e+03       1.95e-02       2.38e+06
#        5             11         2.6686e+06      9.48e+03       4.89e-03       1.16e+06
#        6             12         2.6629e+06      5.69e+03       9.77e-03       9.34e+05
#        7             13         2.6569e+06      6.00e+03       9.77e-03       1.00e+06
#        8             14         2.6512e+06      5.66e+03       9.77e-03       1.17e+06
#        9             15         2.6449e+06      6.36e+03       9.77e-03       1.24e+06
#       10             16         2.6390e+06      5.83e+03       9.77e-03       1.42e+06
#       11             17         2.6323e+06      6.77e+03       9.77e-03       1.51e+06
#       61             68         1.8200e+06      3.40e+04       2.44e-03       1.75e+07
#       62             69         1.7849e+06      3.52e+04       2.44e-03       1.92e+07
#       63             70         1.7465e+06      3.83e+04       2.44e-03       1.94e+07
#       64             71         1.7070e+06      3.95e+04       2.44e-03       2.16e+07
#       65             72         1.6639e+06      4.31e+04       2.44e-03       2.16e+07
#       66             73         1.6193e+06      4.46e+04       2.44e-03       2.42e+07
#       67             74         1.5704e+06      4.89e+04       2.44e-03       2.37e+07
#       68             75         1.5195e+06      5.09e+04       2.44e-03       2.61e+07
#       69             76         1.4634e+06      5.61e+04       2.44e-03       2.58e+07
#       70             77         1.3504e+06      1.13e+05       4.89e-03       4.72e+07
#       71             78         1.0962e+06      2.54e+05       9.77e-03       8.83e+07
#       72             79         9.6287e+05      1.33e+05       1.95e-02       2.05e+08
#       73             80         7.6444e+05      1.98e+05       1.95e-02       4.38e+07
#       74             81         7.3956e+05      2.49e+04       3.91e-02       7.14e+06
#       75             82         7.0795e+05      3.16e+04       7.82e-02       6.27e+06
#       76             83         6.6116e+05      4.68e+04       1.56e-01       1.15e+07
#       77             84         6.2962e+05      3.15e+04       3.13e-01       2.17e+07
#       78             85         6.1708e+05      1.25e+04       3.13e-01       3.53e+06
#       79             86         5.9468e+05      2.24e+04       6.25e-01       4.30e+06
#       80             87         5.5181e+05      4.29e+04       1.25e+00       4.53e+06
#       81             88         4.7339e+05      7.84e+04       2.50e+00       2.50e+06
#       82             89         3.4147e+05      1.32e+05       5.00e+00       5.58e+06
#       83             90         1.5914e+05      1.82e+05       1.00e+01       6.43e+06
#       84             91         2.3176e+04      1.36e+05       2.00e+01       8.52e+06
#       85             92         1.2325e+04      1.09e+04       1.89e+00       1.47e+06
#       86             93         1.2301e+04      2.43e+01       3.70e-02       5.63e+04
#       87             94         1.2301e+04      5.02e-02       7.76e-03       3.57e+03
#       88             95         1.2301e+04      1.60e-04       3.98e-04       1.88e+02
#       89             96         1.2301e+04      5.10e-07       2.47e-05       1.14e+01
# `ftol` termination condition is satisfied.
# Function evaluations 96, initial cost 2.8106e+06, final cost 1.2301e+04, first-order optimality 1.14e+01.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Om det inte fungerade, så kan vi testa med andra startvärden för `A`, `B`, `C` och `D`<br/>
#
# Testa följande istället och byt ut<br/>
# `guessParams = [100, 1, 0, 0.1]` mot `guessParams = [100, 0.1, 0, 0.1]`<br/>
# i koden.
# </div>

# %%
print("anpassad: A={:8g}, B={:8g}, C={:8g}, D={:8g}".format(*optimParams))

display(Markdown(r"$f(t) = {:8g} \sin\left( 2\pi\cdot{:+8g}\,t {:+8g}^o \right)\cdot e^{{ -{:8g}\,t }}$".format(*optimParams)))
# Out:
# anpassad: A= 61.7353, B=0.364276, C=-1.27459, D=0.0131449
# $f(t) =  61.7353 \sin\left( 2\pi\cdot+0.364276\,t -1.27459^o \right)\cdot e^{ -0.0131449\,t }$

# %%
fig, ax = plt.subplots()
ax.plot(tid, vel, label="vinkelhastighet", color="blue", linestyle="", marker="+", markersize=5)
ax.plot(tid, f(tid, *optimParams), "r-", label = "anpassad", linewidth=2)
ax.plot(tid, f(tid, *guessParams), "c-", label = "vår gisnning", linewidth=1, alpha=0.5)
ax.legend()
ax.set_xlabel(r"tid $[s]$")
ax.set_ylabel(r"vinkelhastighet $[^o/s]$")
# Out:
# Text(0, 0.5, 'vinkelhastighet $[^o/s]$')
